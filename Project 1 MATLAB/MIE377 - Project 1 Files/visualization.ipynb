# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
df_prices = pd.read_csv('MIE377_AssetPrices.csv')

# %%
df_prices.columns
# Out:
# Index(['Date', 'F', 'CAT', 'DIS', 'MCD', 'KO', 'PEP', 'WMT', 'C', 'WFC', 'JPM',
#        'AAPL', 'IBM', 'PFE', 'JNJ', 'XOM', 'MRO', 'ED', 'T', 'VZ', 'NEM'],
#       dtype='object')

# %%
df_prices
# Out:
#            Date          F        CAT         DIS         MCD         KO  \
# 0    2001-12-31  10.456407  17.176580   16.979475   17.346429  15.272565
# 1    2002-01-31  10.244614  16.646287   17.258095   17.811709  14.171256
# 2    2002-02-28   9.963390  18.377792   18.847872   17.103959  15.350304
# 3    2002-03-31  11.041418  18.821428   18.913430   18.185243  16.998374
# 4    2002-04-30  10.713322  18.198380   18.995378   18.611204  18.055486
# ..          ...        ...        ...         ...         ...        ...
# 176  2016-08-31  11.783448  78.867041   93.050371  112.561134  41.658137
# 177  2016-09-30  11.287795  85.430473   91.474248  112.269172  40.929462
# 178  2016-10-31  11.118158  81.034152   91.306785  109.553924  41.006833
# 179  2016-11-30  11.326505  92.782453   97.640830  116.978538  39.356110
# 180  2016-12-31  11.487500  90.044419  103.439326  119.381467  40.438769
#
#             PEP        WMT           C        WFC  ...        AAPL  \
# 0     33.128984  42.395824  353.778282  13.948483  ...    1.407228
# 1     34.081553  44.185952  333.314087  14.969376  ...    1.588432
# 2     34.360520  45.681409  318.195410  15.133945  ...    1.394376
# 3     35.142789  45.211974  348.221806  15.940659  ...    1.520962
# 4     35.415743  41.199688  304.483122  16.505358  ...    1.559517
# ..          ...        ...         ...        ...  ...         ...
# 176  103.786877  69.523419   46.895063  48.995360  ...  104.248477
# 177  105.750807  70.185176   46.394090  42.706979  ...  111.077195
# 178  104.224386  68.141514   48.280108  44.375522  ...  111.558644
# 179   98.053077  68.540515   55.575881  51.468766  ...  109.154916
# 180  102.490444  67.742045   58.571992  53.598710  ...  114.389454
#
#             IBM        PFE         JNJ        XOM        MRO         ED  \
# 0     89.640334  22.284334   38.597687  26.048167   6.190980  17.889052
# 1     79.954494  23.302088   37.559272  25.882466   5.788566  18.168292
# 2     72.809670  22.977519   39.898193  27.538159   5.717888  18.328100
# 3     77.172907  22.293130   42.551522  29.225121   5.988188  18.826732
# 4     62.153872  20.391426   41.837416  26.784693   6.042248  19.581418
# ..          ...        ...         ...        ...        ...        ...
# 176  151.572963  33.156826  115.535797  83.222684  14.808597  72.605253
# 177  151.544342  32.270738  114.364368  83.356391  15.587478  72.653496
# 178  146.621656  30.212728  112.292585  79.574410  12.994495  72.894710
# 179  156.155648  30.928649  108.499329  84.108485  17.865441  67.966351
# 180  159.784712  31.255834  112.310940  86.960273  17.123520  71.775272
#
#              T         VZ        NEM
# 0    17.224573  20.271052  16.035618
# 1    16.574412  19.949999  18.326421
# 2    16.747016  20.143688  20.239619
# 3    16.569986  19.842393  23.263735
# 4    13.847963  17.414518  23.952658
# ..         ...        ...        ...
# 176  38.434740  50.578585  37.971056
# 177  38.180890  50.240299  39.038667
# 178  35.013362  47.024235  36.803060
# 179  36.764506  48.783978  32.232485
# 180  40.476170  52.186147  33.903318
#
# [181 rows x 21 columns]

# %%
fig, ax = plt.subplots(10, 2, figsize=(12, 30))

for i in range(1, len(df_prices.columns)):
    j = (i - 1) // 2  # Calculate row index
    k = (i - 1) % 2   # Calculate column index
    ax[j, k].plot(df_prices['Date'].astype('datetime64[D]'), df_prices[df_prices.columns[i]])
    ax[j, k].set_title(df_prices.columns[i])
    ax[j, k].set_ylabel('Asset Price')

plt.tight_layout()
plt.show()

# %%
df_factors = pd.read_csv('MIE377_FactorReturns.csv')

# %%
df_factors.columns
# Out:
# Index(['Date', 'Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev',
#        'LT_Rev', 'RF'],
#       dtype='object')

# %%
df_factors
# Out:
#            Date  Mkt_RF     SMB     HML     RMW     CMA  Mom     ST_Rev  \
# 0    2002-01-31 -0.0144  0.0119  0.0333  0.0435  0.0284  0.0368  0.0155
# 1    2002-02-28 -0.0229 -0.0046  0.0250  0.0762  0.0512  0.0676 -0.0008
# 2    2002-03-31  0.0424  0.0428  0.0110 -0.0136  0.0061 -0.0166  0.0283
# 3    2002-04-30 -0.0520  0.0666  0.0392  0.0457  0.0541  0.0795  0.0206
# 4    2002-05-31 -0.0138 -0.0307  0.0168  0.0227  0.0242  0.0297 -0.0268
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 175  2016-08-31  0.0050  0.0172  0.0334 -0.0133 -0.0039 -0.0312 -0.0034
# 176  2016-09-30  0.0025  0.0174 -0.0149 -0.0229 -0.0008 -0.0058  0.0009
# 177  2016-10-31 -0.0202 -0.0401  0.0416  0.0119  0.0024  0.0065  0.0272
# 178  2016-11-30  0.0486  0.0681  0.0829 -0.0010  0.0370 -0.0415  0.0004
# 179  2016-12-31  0.0182  0.0041  0.0358  0.0099 -0.0030 -0.0042 -0.0098
#
#      LT_Rev      RF
# 0    0.0355  0.0014
# 1    0.0407  0.0013
# 2    0.0209  0.0013
# 3    0.0614  0.0015
# 4    0.0232  0.0014
# ..      ...     ...
# 175  0.0054  0.0002
# 176  0.0178  0.0002
# 177 -0.0111  0.0002
# 178  0.0236  0.0001
# 179 -0.0255  0.0003
#
# [180 rows x 10 columns]

# %%
fig, ax = plt.subplots(4, 2, figsize=(12, 12))

for i in range(1, len(df_factors.columns)-1):
    j = (i - 1) // 2  # Calculate row index
    k = (i - 1) % 2   # Calculate column index
    ax[j, k].plot(df_factors['Date'].astype('datetime64[D]'), df_factors[df_factors.columns[i]])
    ax[j, k].set_title(df_factors.columns[i])
    ax[j, k].set_ylabel('Factor Returns')

plt.tight_layout()
plt.show()

# %%
plt.plot(df_factors['Date'].astype('datetime64[D]'), df_factors['RF'])
plt.title('RF')
plt.ylabel('Returns')
plt.show()
