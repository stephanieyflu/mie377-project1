# %% [markdown]
# # MMF1921/MIE377 - Backtesting Template
#
# The purpose of this program is to provide a template with which to develop Project 2. The project requires you to test different models  (and/or different model combinations) to create an asset management algorithm.
#
# This template will be used by the instructor and TA to assess your trading algorithm using different datasets.
#
# # PLEASE DO NOT MODIFY THIS TEMPLATE (for Project submission purposes)
#
# # 1. Read input files

# %%
import time
import math
from scipy.stats import gmean
import matplotlib.pyplot as plt
from services.project_function import *
import pandas as pd

# %%
df = pd.read_csv("AssetPrices_1.csv", index_col=0)
print(df.shape)
no_assets = df.shape[1]
# Out:
# (127, 21)

# %%
llambdass = []
times = []
sharpes = []
turnovers = []

for llambdas in range(1, no_assets+1):

    adjClose = pd.read_csv("MIE377_AssetPrices.csv", index_col=0)
    factorRet = pd.read_csv("MIE377_FactorReturns.csv", index_col=0)

    adjClose.index = pd.to_datetime(adjClose.index)
    factorRet.index = pd.to_datetime(factorRet.index)

    # Initial budget to invest ($100,000)
    initialVal = 100000

    # Length of investment period (in months)
    investPeriod = 6

    # divide the factor returns by  100
    factorRet = factorRet/100

    #rf and factor returns
    riskFree = factorRet['RF']
    factorRet = factorRet.loc[:,factorRet.columns != 'RF'];

    #Identify the tickers and the dates
    tickers = adjClose.columns
    dates   = factorRet.index

    # Calculate the stocks monthly excess returns
    # pct change and drop the first null observation
    returns = adjClose.pct_change(1).iloc[1:, :]


    returns = returns  - np.diag(riskFree.values) @ np.ones_like(returns.values)
    # Align the price table to the asset and factor returns tables by discarding the first observation.
    adjClose = adjClose.iloc[1:,:]

    assert adjClose.index[0] == returns.index[0]
    assert adjClose.index[0] == factorRet.index[0]

    # Start of out-of-sample test period
    testStart = returns.index[0] + pd.offsets.DateOffset(years=5)

    #End of the first investment period
    testEnd = testStart + pd.offsets.DateOffset(months=investPeriod) -  pd.offsets.DateOffset(days = 1)

    # End of calibration period
    calEnd = testStart -  pd.offsets.DateOffset(days = 1)

    # Total number of investment periods
    NoPeriods = math.ceil((returns.index[-1].to_period('M') - testStart.to_period('M')).n / investPeriod)

    # Number of assets
    n  = len(tickers)

    # Preallocate space for the portfolio weights (x0 will be used to calculate
    # the turnover rate)
    x  = np.zeros([n, NoPeriods])
    x0 = np.zeros([n, NoPeriods])

    # Preallocate space for the portfolio per period value and turnover
    currentVal = np.zeros([NoPeriods, 1])
    turnover   = np.zeros([NoPeriods, 1])

    #Initiate counter for the number of observations per investment period
    toDay = 0

    # Measure runtime: start the clock
    start_time = time.time()

    # Empty list to measure the value of the portfolio over the period
    portfValue = []

    for t in range(NoPeriods):
        # Subset the returns and factor returns corresponding to the current calibration period.
        periodReturns = returns[returns.index <= calEnd]
        periodFactRet = factorRet[factorRet.index <= calEnd]

        current_price_idx = (calEnd - pd.offsets.DateOffset(months=1) <= adjClose.index)&(adjClose.index <= calEnd)
        currentPrices = adjClose[current_price_idx]

        # Subset the prices corresponding to the current out-of-sample test period.
        periodPrices_idx = (testStart <= adjClose.index)&(adjClose.index <= testEnd)
        periodPrices = adjClose[periodPrices_idx]

        assert len(periodPrices) == investPeriod
        assert len(currentPrices) == 1
        # Set the initial value of the portfolio or update the portfolio value
        if t == 0:
            currentVal[0] = initialVal
        else:
            currentVal[t] = currentPrices @  NoShares.values.T
            #Store the current asset weights (before optimization takes place)
            x0[:,t] = currentPrices.values*NoShares.values/currentVal[t]

        #----------------------------------------------------------------------
        # Portfolio optimization
        # You must write code your own algorithmic trading function
        #----------------------------------------------------------------------
        x[:,t] = project_function(periodReturns, periodFactRet, x0[:,t])

        #Calculate the turnover rate
        if t > 0:
            turnover[t] = np.sum( np.abs( x[:,t] - x0[:,t] ) )

        # Number of shares your portfolio holds per stock
        NoShares = x[:,t]*currentVal[t]/currentPrices

        # Update counter for the number of observations per investment period
        fromDay = toDay
        toDay   = toDay + len(periodPrices)

        # Weekly portfolio value during the out-of-sample window
        portfValue.append(periodPrices@ NoShares.values.T)

        # Update your calibration and out-of-sample test periods
        testStart = testStart + pd.offsets.DateOffset(months=investPeriod)
        testEnd   = testStart + pd.offsets.DateOffset(months=investPeriod) - pd.offsets.DateOffset(days=1)
        calEnd    = testStart - pd.offsets.DateOffset(days=1)

    portfValue = pd.concat(portfValue, axis = 0)
    end_time = time.time()

    #--------------------------------------------------------------------------
    # 3.1 Calculate the portfolio average return, standard deviation, Sharpe ratio and average turnover.
    #-----------------------------------------------------------------------
    # Calculate the observed portfolio returns
    portfRets = portfValue.pct_change(1).iloc[1:,:]

    # Calculate the portfolio excess returns
    portfExRets = portfRets.subtract(riskFree[(riskFree.index >= portfRets.index[0])&(riskFree.index <= portfRets.index[-1])], axis = 0)

    # Calculate the portfolio Sharpe ratio
    SR = ((portfExRets + 1).apply(gmean, axis=0) - 1)/portfExRets.std()

    # Calculate the average turnover rate
    avgTurnover = np.mean(turnover[1:])

    #Print Sharpe ratio and Avg. turnover to the console
    print(llambdas)
    print("Elasped time is "+ str(end_time - start_time) + ' seconds')
    print('Sharpe ratio: ', str(SR[0]))
    print('Avg. turnover: ', str(avgTurnover))
    print('\n')

    llambdass.append(llambdas)
    times.append(end_time - start_time)
    sharpes.append(SR[0])
    turnovers.append(avgTurnover)
# Out:
# periodReturns: (60, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var2
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 6.351e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 3.564e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 6.351e-03 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (66, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var111
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.952e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 2.016e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.952e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (72, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var220
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 2.119e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 2.253e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 2.119e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 3.991e-03 seconds
# periodReturns: (78, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var329
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.638e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 5.132e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.638e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (84, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var438
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 4.414e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 9.456e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 4.414e-03 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 1.547e-02 seconds
# periodReturns: (90, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var547
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.426e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 8.360e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.426e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (96, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var656
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 2.121e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 1.140e+01
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 2.121e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 2.007e-03 seconds
# periodReturns: (102, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var765
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.591e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 1.447e+01
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.591e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (108, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var874
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 2.576e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 1.339e+01
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 2.576e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 4.220e-03 seconds
# periodReturns: (114, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var983
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.730e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 6.387e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.730e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 4.021e-03 seconds
# periodReturns: (120, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1092
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.380e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 2.364e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.380e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 1.133e-02 seconds
# periodReturns: (126, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1201
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 8.110e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 1.971e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 8.110e-03 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 2.897e-03 seconds
# periodReturns: (132, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1310
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.615e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 3.983e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.615e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 1.555e-03 seconds
# periodReturns: (138, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1419
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:18 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:18 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:18 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:18 AM: Finished problem compilation (took 1.606e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:18 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:18 AM: Optimal value: 3.742e+00
# (CVXPY) Mar 18 04:14:18 AM: Compilation took 1.606e-02 seconds
# (CVXPY) Mar 18 04:14:18 AM: Solver (including time spent in interface) took 3.001e-03 seconds
# periodReturns: (144, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1528
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:18 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:19 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:19 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:19 AM: Finished problem compilation (took 1.635e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:19 AM: Optimal value: 4.616e+00
# (CVXPY) Mar 18 04:14:19 AM: Compilation took 1.635e-02 seconds
# (CVXPY) Mar 18 04:14:19 AM: Solver (including time spent in interface) took 3.513e-03 seconds
# periodReturns: (150, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1637
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:19 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:19 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:19 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:19 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:19 AM: Finished problem compilation (took 1.343e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:19 AM: Optimal value: 4.760e+00
# (CVXPY) Mar 18 04:14:19 AM: Compilation took 1.343e-02 seconds
# (CVXPY) Mar 18 04:14:19 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (156, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1746
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:19 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:19 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:19 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:19 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:19 AM: Finished problem compilation (took 1.663e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:19 AM: Optimal value: 3.337e+00
# (CVXPY) Mar 18 04:14:19 AM: Compilation took 1.663e-02 seconds
# (CVXPY) Mar 18 04:14:19 AM: Solver (including time spent in interface) took 1.698e-02 seconds
# periodReturns: (162, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1855
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:19 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:19 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:19 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:19 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:19 AM: Finished problem compilation (took 1.757e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:19 AM: Optimal value: 3.211e+00
# (CVXPY) Mar 18 04:14:19 AM: Compilation took 1.757e-02 seconds
# (CVXPY) Mar 18 04:14:19 AM: Solver (including time spent in interface) took 1.514e-02 seconds
# periodReturns: (168, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var1964
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:19 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:19 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:19 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:19 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:19 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:19 AM: Finished problem compilation (took 1.455e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:19 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:19 AM: Optimal value: 4.558e+00
# (CVXPY) Mar 18 04:14:19 AM: Compilation took 1.455e-02 seconds
# ...
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 3.742e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 2.081e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 2.993e-03 seconds
# periodReturns: (144, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var45128
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:45 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:45 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:45 AM: Finished problem compilation (took 3.004e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 4.616e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 3.004e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 3.998e-03 seconds
# periodReturns: (150, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var45237
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:45 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:45 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:45 AM: Finished problem compilation (took 1.961e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 4.760e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 1.961e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 3.014e-03 seconds
# periodReturns: (156, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var45346
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:45 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:45 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:45 AM: Finished problem compilation (took 2.000e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 3.337e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 2.000e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 3.993e-03 seconds
# periodReturns: (162, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var45455
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:45 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:45 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:45 AM: Finished problem compilation (took 1.500e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 3.211e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 1.500e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 3.010e-03 seconds
# periodReturns: (168, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var45564
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:45 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:45 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:45 AM: Finished problem compilation (took 1.908e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 4.558e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 1.908e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 0.000e+00 seconds
# periodReturns: (174, 20)
# x0: 20
# Index(['Mkt_RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom   ', 'ST_Rev', 'LT_Rev'], dtype='object')
# (20,)
# var45673
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Mar 18 04:14:45 AM: Your problem has 41 variables, 6 constraints, and 0 parameters.
# (CVXPY) Mar 18 04:14:45 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 18 04:14:45 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 18 04:14:45 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Mar 18 04:14:45 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Mar 18 04:14:45 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction Dcp2Cone
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 18 04:14:45 AM: Applying reduction ECOS
# (CVXPY) Mar 18 04:14:45 AM: Finished problem compilation (took 3.655e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Invoking solver ECOS  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 18 04:14:45 AM: Problem status: optimal
# (CVXPY) Mar 18 04:14:45 AM: Optimal value: 7.102e+00
# (CVXPY) Mar 18 04:14:45 AM: Compilation took 3.655e-02 seconds
# (CVXPY) Mar 18 04:14:45 AM: Solver (including time spent in interface) took 4.455e-03 seconds
# 21
# Elasped time is 1.4741880893707275 seconds
# Sharpe ratio:  0.13504089885718196
# Avg. turnover:  0.24983824041874997

# %%
df = pd.DataFrame({'llambdas': llambdas, 'Time': times, 'Sharpe Ratio': sharpes, 'Turnover': turnovers},
                  index=llambdass)
df
# Out:
#     llambdas      Time  Sharpe Ratio  Turnover
# 1         21  0.949522      0.135041  0.249838
# 2         21  1.065808      0.135041  0.249838
# 3         21  1.017259      0.135041  0.249838
# 4         21  1.103478      0.135041  0.249838
# 5         21  1.292917      0.135041  0.249838
# 6         21  1.456222      0.135041  0.249838
# 7         21  1.276850      0.135041  0.249838
# 8         21  1.294577      0.135041  0.249838
# 9         21  1.458423      0.135041  0.249838
# 10        21  1.525610      0.135041  0.249838
# 11        21  1.409750      0.135041  0.249838
# 12        21  1.346248      0.135041  0.249838
# 13        21  1.171515      0.135041  0.249838
# 14        21  1.007919      0.135041  0.249838
# 15        21  1.254662      0.135041  0.249838
# 16        21  1.216937      0.135041  0.249838
# 17        21  1.292989      0.135041  0.249838
# 18        21  1.227327      0.135041  0.249838
# 19        21  1.268645      0.135041  0.249838
# 20        21  1.262213      0.135041  0.249838
# 21        21  1.474188      0.135041  0.249838

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

plt.title('Sharpe Ratio and Turnover with respect to number of PCs selected as factors')

ax1.plot(df['llambdas'].values, df['Sharpe Ratio'].values, label='Sharpe Ratio', marker='.', color='tab:blue')
ax1.plot([], [], label='Turnover', marker='.', color='tab:green')
ax2.plot(df['llambdas'].values, df['Turnover'].values, label='Turnover', marker='.', color='tab:green')
ax1.set_xlabel('Number of PCs used as factors')
ax1.set_ylabel('Sharpe Ratio')
ax2.set_ylabel('Turnover')

ax1.legend(loc='upper right')
plt.xticks(range(1, no_assets+1))
plt.tight_layout()
plt.show()

# %%
#--------------------------------------------------------------------------
# 3.2 Portfolio wealth evolution plot
#--------------------------------------------------------------------------
# Calculate the dates of the out-of-sample period

fig = plt.figure(1)
portfValue.plot(title = 'Portfolio wealth evolution',
                ylabel = 'Total wealth',
                figsize = (6, 3),
                legend = False)
plt.savefig("images/wealth.svg")

#--------------------------------------------------------------------------
# 3.3 Portfolio weights plot
#--------------------------------------------------------------------------
# Portfolio weights

fig2 = plt.figure(2);
x[x < 0] = 0
weights = pd.DataFrame(x, index = tickers)
weights.columns = [col + 1 for col in weights.columns]
weights.T.plot.area(title = 'Portfolio weights',
                  ylabel = 'Weights', xlabel = 'Rebalance Period',
                  figsize = (6, 3),
                  legend = True, stacked = True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("images/weights.svg");
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Program End

# %% [markdown]
# ### 0.12% maximum absolute difference between the returns generated via Python and returns generated via MATLAB can be observed
#
# ### Terminal wealth between MATLAB and Python is within 0.1%
